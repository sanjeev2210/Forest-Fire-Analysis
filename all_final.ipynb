# %%
import pandas as pd
import numpy as np

c=0

# %%
out=pd.read_csv('C:\\Users\\Rahul\\Downloads\\train.csv')
#out.head()
#out.columns.values
train=np.asarray(out)
cnt= 0

# %%
for i in range(0,train.shape[0]):
    DC = train[i][2]
    RH = train[i][5]
    temp =train[i][4]
    DMC = train[i][1]
    FFMC = train[i][0]
    ISI = train[i][3]
    wind = train[i][6]
    if DC > 458.625 and DC > 545.618:
        c=c+1
    elif DC > 458.625 and RH <= 55.735:
        c = c+1
    elif DC > 458.625 and RH > 55.735 and temp <= 18.71 and temp > 16.864:
        c = c+1
    elif DC > 458.625 and RH > 55.735 and temp > 18.710:
        c = c+1
    elif DC > 458.625 and RH <= 55.735 and wind <= 6.477 and wind <= 4.469:
        c = c+1
    elif DC > 458.625 and RH <= 55.735 and wind <= 6.477 and wind > 4.469 and RH <= 48.083:
        c = c+1
    elif DC > 458.625 and RH > 55.735 and wind <= 2.399:
        c = 1
    elif DC > 458.625 and temp > 15.140  and temp <= 20.220 and temp <= 16.079 and temp > 15.588:
        c = 1
    elif DC > 458.625 and temp > 15.140 and temp <= 20.220 and temp > 16.079:
        c = c+1
    elif DC > 458.625 and temp > 15.140 and temp > 20.220:
        c = 1
    elif DC > 458.62 and temp > 15.140  and temp > 20.220:
        c = 1
    elif DC > 458.625 and RH <= 55.735 and wind <= 6.477 and wind > 4.469 and RH <= 48.083:
        c = 1
    elif DC > 458.625 and RH > 55.735 and wind <= 2.399:
        c = 1
    elif DC > 458.625 and wind <= 5.945:
        c = 1
    elif DMC > 65.344 and DMC <= 110.371 and DMC <= 92.345:
        c = 1
    elif DMC > 65.344 and DMC <= 110.371 and DMC > 92.345 and DMC > 95.758:
        c = 1
    elif DMC > 65.344 and DMC > 110.371 and DMC <= 143.206:
        c = 1
    elif DMC > 65.344 and DMC > 110.371 and DMC > 143.206 and DMC > 147.904:
        c = 1
    elif DC > 458.625 and DC > 545.618 and DMC <= 120.188 and DMC > 62.970:
        c = 1
    elif DC > 458.625 and DC > 545.618 and DMC > 120.188:
        c = 1
    elif DC > 437.550 and RH <= 50.500:
        c = 1
    elif DC > 437.550 and RH > 50.500 and temp > 15.550 and DMC > 110 and DC > 632:
        c = 1
    elif DMC > 65.344 and DMC <= 110.371:
        c = 1
    elif DMC > 65.344 and DMC > 110.371 and DMC <= 143.206:
        c = 1
    elif DMC > 65.344 and DMC > 110.371 and DMC > 143.206 and DMC > 147.904:
        c = 1
    elif DMC > 65.344 and RH <= 57.907 and RH <= 43.647:
        c = 1
    elif DMC > 65.344 and RH <= 57.90 and RH > 43.647 and RH <= 52.575 and RH <= 50.571:
        c = 1
    elif DMC > 65.34 and RH <= 57.90 and RH > 43.647 and RH > 52.575 and DMC > 111.331:
        c = 1
    elif DMC <= 65.344 and temp > 19.836:
        c = 1
    elif DMC > 65.344 and temp > 15.540:
        c = 1
    elif DMC > 65.344 and wind <= 6.083:
        c = 1
    elif FFMC > 87.496 and FFMC > 90.440:
        c = 1
    elif DC > 458.625 and FFMC <= 87.741:
        c = 1
    elif DC > 458.625 and FFMC > 87.741 and FFMC > 89.071 and DC > 543.615:
        c = 1
    elif DMC > 65.344:
        c = 1
    elif RH <= 68.333 and FFMC > 88.556 and RH <= 56.075:
        c = 1
    elif temp <= 16.985 and temp > 14.287 and temp > 16.152:
        c = 1
    elif temp > 16.985 and temp <= 20.888 and temp > 17.609:
        c = 1
    elif temp > 16.985 and temp > 20.888:
        c = 1
    elif FFMC > 87.496 and FFMC > 90.440 and wind <= 5.745 and wind <= 3.677:
        c = 1
    elif FFMC > 87.496 and FFMC > 90.440 and wind <= 5.745 and wind > 3.677 and FFMC > 91.385:
        c = 1
    elif FFMC > 87.496 and FFMC > 90.440 and wind > 5.745 and FFMC > 92.083:
        c = 1
    elif RH <= 68.333 and RH <= 59.821 and RH <= 44.983:
        c = 1
    elif RH <= 68.333 and RH <= 59.821 and RH > 44.983 and RH <= 57.250:
        c = 1
    elif temp <= 16.985 and temp > 14.287 and RH <= 55.827 and temp <= 15.990 and RH > 48.089:
        c = c  +1
    elif temp <= 16.985 and temp > 14.287 and RH <= 55.827 and temp > 15.990:
        c = 1
    elif temp > 16.985 and RH <= 58.962 and temp <= 20.831 and RH > 27.219:
        c = 1
    elif temp > 16.985 and RH <= 58.962 and temp > 20.831:
        c = 1
    elif temp <= 16.985 and temp > 14.287 and temp > 16.152:
        c = 1
    elif temp > 16.985 and temp <= 20.888 and temp > 17.609:
        c = 1
    elif DC > 458.625 and RH > 55.735 and RH <= 60.451 and FFMC > 91.691:
        c = 1 
    elif DC > 458.625 and FFMC <= 87.741:
        c = 1
    elif DC > 458.625 and FFMC > 87.741 and FFMC > 89.071 and DC > 543.615:
        c = 1
    elif DMC > 65.344 and RH <= 57.907 and RH <= 43.647:
        c = 1
    elif DMC > 65.344 and RH <= 57.907 and RH > 43.647 and RH <= 52.575 and RH <= 50.571:
        c  = 1
    elif DMC > 65.344 and RH <= 57.907 and RH > 43.647 and RH > 52.575:
        c = 1
    elif DMC <= 65.344 and temp > 19.836:
        c = 1
    elif DMC > 65.344 and temp > 15.540:
        c = 1
    elif RH <= 68.333 and RH <= 59.821 and RH > 44.983 and ISI <= 6.878 and ISI > 5.506:
        c = 1
    elif RH <= 68.333 and RH <= 59.821 and RH > 44.983 and ISI > 6.878:
        c =1
    elif DMC > 53.700 and temp > 15.550 and FFMC > 90.600 and temp > 17.850:
        c = c +1
    elif DMC > 53.700 and temp > 15.550 and FFMC > 90.600 and temp > 17.850:
        c = 1
    elif temp > 15.850 and temp <= 18.250 and FFMC <= 91.800 and FFMC > 90.600 and FFMC <= 91.300:
        c = 1
    elif FFMC > 90.850 and RH <= 50.500 and FFMC > 91.750:
        c =  1
    elif FFMC > 90.850 and FFMC <= 91.750 and ISI <= 7.700:
        c =  c +1
    elif DMC > 53.700 and FFMC > 90.600 and FFMC > 91.550:
        c = 1
    elif DMC > 53.700 and FFMC > 90.600 and FFMC > 91.550:
        c = 1
    elif DMC > 53.700 and temp > 15.550 and temp > 17.850 and DMC > 65.400 and DMC > 97.100:
        c = 1
    elif DC > 61 and DC <= 751.500 and wind > 2.700 and wind <= 4.900 and DC > 721.400:
        c = 1
    elif DMC > 73.400 and DMC <= 105.800:
        c = 1
    elif DC > 613 and DC <= 751.500 and DMC > 129.500 and DC <= 661.300:
        c = 1
    elif DC > 613 and DC <= 751.500 and DMC > 129.500 and DC > 661.300:
        c = 1
    elif DC > 458.625 and DC <= 545.618:
        c = 2
    elif DC > 458.625 and DC <= 545.618:
        c = 2
    elif DC > 458.625 and RH > 55.735:
        c = 2
    elif DC > 458.625 and RH > 55.735 and temp <= 18.710 and temp > 16.864:
        c = 2
    elif DC > 458.625 and RH <= 55.735 and wind <= 6.477 and wind > 4.469 and RH <= 48.083:
        c = 2
    elif DC > 458.625 and temp > 15.140 and temp <= 20.220 and temp > 16.079:
        c = 2
    elif DC > 458.625 and RH <= 55.735 and wind <= 6.477and wind > 4.469 and RH <= 48.083:
        c =2
    elif DC > 458.625 and wind > 5.945:
        c = 2
    elif DMC > 65.344 and DMC > 110.371 and DMC > 143.206 and DMC <= 147.904:
        c  = 2
    elif DC > 458.625 and DC > 545.618 and DMC <= 120.188 and DMC <= 62.970:
        c =  c +  1
    elif DC > 437.550 and RH > 50.500 and temp > 15.550 and DMC <= 110:
        c = 2
    elif DC > 437.550 and RH > 50.500 and temp <= 15.550:
        c = 2
    elif DC > 437.550 and RH > 50.500 and temp > 15.550 and DMC > 110 and DC <= 632:
        c = 2
    elif DMC <= 65.344 and DMC > 55.140:
        c = 2
    elif DMC > 65.344 and DMC > 110.371 and DMC > 143.206 and DMC <= 147.904:
        c = 2
    elif DMC <= 65.344 and DMC > 55.140:
        c = 2
    elif DMC > 65.344 and RH <= 57.907 and RH > 43.647 and RH <= 52.575 and RH > 50.571:
        c = 2
    elif DMC > 65.344 and RH <= 57.907 and RH > 43.647 and RH > 52.575 and DMC <= 111.331:
        c = 2
    elif DMC > 65.344 and RH > 57.907:
        c =2
    elif DMC > 65.344 and temp <= 15.540:
        c = 2
    elif DMC <= 65.344 and temp <= 19.836:
        c = 2
    elif DMC <= 65.344 and DMC > 55.140:
        c = 2
    elif DMC > 65.344 and wind > 6.083:
        c = c +1
    elif DC > 458.625 and FFMC > 87.741 and FFMC <= 89.071:
        c = 2
    elif DC > 458.625 and FFMC > 87.741 and FFMC > 89.071 and DC <= 543.615:
         c = 2
    elif DMC <= 65.344 and DMC > 55.140:
        c = 2
    elif FFMC > 87.496 and FFMC <= 90.440 and ISI <= 9.063 and ISI > 7.527:
        c = c +1 
    elif RH <= 68.333 and FFMC > 88.556 and RH > 56.075:
        c = 2
    elif RH <= 68.333 and RH <= 59.821 and RH > 44.983 and RH > 57.250:
        c = 2
    elif RH <= 68.333 and RH > 59.821:
        c = 2
    elif RH > 68.333 and RH <= 80.453:
        c = 2
    elif temp <= 16.985 and temp <= 14.287 and RH > 62.326 and temp > 9.995:
        c = 2
    elif temp <= 16.985 and temp > 14.287 and RH > 55.827:
        c = 2
    elif temp > 16.985 and RH > 58.962:
        c = 2
    elif DC > 437.550 and RH > 50.500 and temp <= 15.550:
        c = 2
    elif DC > 437.550 and RH > 50.500 and temp > 15.550 and DMC > 110 and DC <= 632:
        c = 2
    elif DC > 437.550 and RH > 50.500 and temp > 15.550 and DMC <= 110:
        c = 2
    elif DMC > 53.700 and DMC > 102.250 and DMC <= 148.300 and DMC > 141.850:
        c = 2
    elif DMC > 53.700 and RH > 50.500 and DMC <= 149.950 and RH <= 65 and DMC <= 110:
        c = 2
    elif DMC > 53.700 and RH > 50.500 and DMC <= 149.950 and RH <= 65 and DMC > 110 and DMC > 126.800:
        c = 2
    elif temp <= 15.850 and RH > 55.500 and temp <= 11.550 and temp > 7.750 and RH > 73 and RH <= 88:
        c = 2
    elif temp <= 15.850 and RH > 55.50 and temp > 11.550:
        c = 2
    elif temp > 15.850 and temp <= 18.250 and RH > 36 and RH > 49.500:
        c  = 2
    elif wind > 5.150 and wind <= 7.800and wind > 6.500:
        c = 2
    elif DC > 437.550 and DC <= 626.650 and area <= 0.845 and DC <= 555.150:
        c = 2
    elif DC > 437.550 and DC <= 626.650 and area <= 0.845 and DC > 555.150 and DC > 590.650:
        c = 2
    elif DC > 437.550 and DC > 626.650 and ISI <= 7.150 and DC <= 744.150 and DC > 708.350 and ISI > 5.950:
        c = 2
    elif DMC > 53.700 and DMC > 102.250 and DMC <= 148.300 and DMC > 141.850:
        c = 2
    elif DMC > 53.700 and DMC > 102.250 and DMC <= 148.300 and DMC > 141.850:
        c = 2
    elif DMC > 53.700 and DMC > 102.250 and DMC <= 148.300 and DMC > 141.850:
        c =  c +  1
    elif DC > 437.550 and DC > 626.650 and ISI <= 7.150 and DC <= 744.150 and DC > 708.350 and ISI > 5.950:
        c = 2
    elif DC > 437.550 and DC <= 626.650 and area <= 0.845 and DC > 555.150 and DC > 590.650:
        c = 2
    elif DC > 437.550 and DC <= 626.650 and area <= 0.845 and DC <= 555.150:
        c = 2
    elif wind > 5.150 and wind <= 7.800 and wind > 6.500:
        c = 2
    elif temp > 15.850 and temp <= 18.250 and RH > 36 and RH > 49.500:
        c = 2
    elif temp <= 15.850 and temp > 9.700 and temp <= 10.450:
        c = 2
    elif FFMC >  90.850 and RH > 50.500 and RH > 61.500:
        c = 2
    elif temp <= 15.850 and FFMC > 88.150 and FFMC <= 89.050:
        c = 2
    elif temp <= 15.850 and FFMC > 88.150 and FFMC > 89.050 and FFMC > 91.800 and FFMC <= 92.750:
        c = 2
    elif temp > 15.850   and temp <= 18.250 and FFMC <= 91.800 and FFMC > 90.600 and FFMC > 91.300 and FFMC <= 91.600:
        c = 2
    elif FFMC <= 90.850 and FFMC > 88.150 and wind > 3.800 and FFMC <= 89:
        c = 2
    elif FFMC <= 90.850 and FFMC > 88.150 and wind > 3.800 and FFMC > 89 and FFMC > 89.450 and FFMC <= 90.350 :    
        c = 2
    elif RH > 50.500 and RH <= 76 and RH > 62.500:
        c = 2
    elif temp <= 15.850 and RH > 55.500 and temp <= 11.550 and temp > 7.750 and RH > 73 and RH <= 88:
        c = 2
    elif temp <= 15.850 and RH > 55.500 and temp > 11.550:
        c = 2
    if DMC <= 65.344 and DMC <= 55.140:
        c = 3
    elif DMC > 65.344 and DMC <= 110.371 and DMC > 92.345 and DMC <= 95.758:
        c = 3
    elif DMC <= 65.344 and temp <= 19.836:
        c = 3
    elif FFMC <= 87.496:
        c = 3
    elif FFMC > 87.496 and FFMC <= 90.440:
        c = 3
    elif DMC <= 65.344 and DMC <= 55.140:
        c = 3
    elif FFMC > 87.496 and FFMC <= 90.440 and ISI <= 9.063 and ISI <= 7.527:
        c = 3
    elif FFMC > 87.496 and FFMC <= 90.440 and ISI <= 9.063 and ISI <= 7.527:
        c = 3
    elif RH <= 68.333 and FFMC <= 88.556:
        c =3
    elif temp <= 16.985 and temp <= 14.287:
        c = 3
    elif temp <= 16.985 and temp > 14.287 and temp <= 16.152:
        c =  c  +1 
    elif temp > 16.985 and temp <= 20.888 and temp <= 17.609:
        c =3
    elif FFMC > 87.496 and FFMC > 90.440 and wind <= 5.745 and wind > 3.677 and FFMC <= 91.385:
        c = 3
    elif FFMC > 87.496 and FFMC > 90.440 and wind > 5.745 and FFMC <= 92.083:
        c =3
    elif RH > 68.333 and RH > 80.453:
        c = 3
    elif temp <= 16.985 and temp <= 14.287 and RH <= 62.326:
        c = 3
    elif temp <= 16.985 and temp <= 14.287 and RH > 62.326 and temp <= 9.995:
        c = 3
    elif temp <= 16.985 and temp > 14.287 and RH <= 55.827 and temp <= 15.990 and RH <= 48.089:
        c = 3
    elif temp > 16.985 and RH <= 58.962 and temp <= 20.831 and RH <= 27.219:
        c =3
    elif temp <= 16.985 and temp <= 14.287:
        c = 3
    elif FFMC > 90.400 and FFMC <= 92.100 and RH <= 27:
        c = 3
    elif temp <= 15.800 and FFMC <= 88.600:
        c = 3
    elif DMC > 35.800 and DMC <= 73.400 and FFMC > 85.100:
        c = 3
    elif DMC > 53.700 and RH <= 50.500 and DMC <= 97.100 and DMC > 88.850 and DMC <= 94.200 and DMC > 92.300:
        c = 3
    elif DMC > 53.700 and temp > 15.550 and temp > 17.850 and DMC > 65.400 and DMC <= 97.100 and DMC > 92.300 and DMC <= 94.200:
        c = 3
    elif DMC > 53.700 and FFMC <= 90.600 and FFMC > 90.350:
        c = 3
    elif FFMC <= 90.850  and FFMC <= 88.150  and ISI <= 1.950  and FFMC <= 80.550:
        c = 3
    elif FFMC <= 90.850 and FFMC <= 88.150 and ISI > 1.950:
        c = 3
    elif FFMC <= 90.850 and FFMC > 88.150 and ISI > 6.950 and FFMC > 89.050:
        c = 3
    elif FFMC > 90.850 and FFMC <= 91.750 and ISI > 7.700 and FFMC > 91.600:
        c = 3
    elif FFMC <= 90.850 and FFMC <= 88.150 and RH <= 37 and RH <= 27.500:
        c = 3
    elif FFMC <= 90.850 and FFMC <= 88.150 and RH > 37:
        c = 3
    elif FFMC > 90.850  and RH <= 50.500  and FFMC <= 91.750  and RH <= 30.500  and FFMC > 91.250:
        c = 3
    elif temp <= 15.850 and FFMC <= 88.150:
        c = 3
    elif temp <= 15.850 and FFMC > 88.150 and FFMC > 89.050 and FFMC <= 91.800:
        c = 3
    elif temp <= 15.850 and RH > 55.500 and temp <= 11.550 and temp > 7.750 and RH > 73 and RH > 88:
        c = 3
    elif temp <= 15.850 and RH > 55.500 and temp <= 11.550 and temp > 7.750 and RH <= 73:
        c = 3
    elif temp <= 15.850 and RH > 55.500 and temp <= 11.550 and temp > 7.750 and RH > 73 and RH > 88:
        c = 3
    print c
